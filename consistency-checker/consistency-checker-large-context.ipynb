# %% [markdown]
# # Getting feedback on the entire JASMIN docs stack from GPT5
#
# Redo as follows:
# - [ ] Parse latest docs
# - [ ] Structure them as input
# - [ ] Improve the prompt
# - [ ] Ask the prompt to provide Markdown content, and to separate out:
#     - [ ] Summary
#     - [ ] Structural recommendations
#     - [ ] Typos and formatting issues
#     - [ ] Factual inconsistencies
# - [ ] Ask it to point to the relevant pages and sections where changes are recommended
# - [ ] Ask it to tabulate its recommendations
# - [ ] Ask it to make suggestions for rewording

# %%
# Import openai library and other necessary modules 
# Then write a prompt expanded from:
# 1. I'm going to send you a large document
# 2. Create an internal summary of all key information
# 3. Identify any inconsistencies or errors in the document
# 4. Suggest corrections or improvements to enhance clarity and coherence
# Send this prompt to the OpenAI API, along with the document (which will be a large string)

from pathlib import Path
from openai import OpenAI
import pandas as pd
from dotenv import load_dotenv
load_dotenv(Path("../../../../../../msc-project/work/.env"))

client = OpenAI()

# Reformat data into a prompt for the OpenAI API
prompt_template = """
1. I'm going to send you a large document
2. Create an internal summary of all key information
3. Identify any inconsistencies or errors in the document
4. Suggest corrections or improvements to enhance clarity and coherence

Here is the documentation I would like you to check:

<DOCUMENTATION_START>

{data}

<DOCUMENTATION_END>
"""

def send(data, model="gpt-5-mini"):
        # Send the prompt and document to the OpenAI API
    response = client.responses.create(
        model=model,
        input=prompt_template.format(data=data)
    )
    return response

# %%
data_path = Path("../../../../../../../ai-mini-projects/jasmin-docs-chatbot/jasmin_docs.csv")
data = pd.read_csv(data_path)

# %%
data = data[data.contents.notnull()] # Remove NaNs

content = []

for _, row in data.iterrows():
    content.append("<SECTION>\n")
    content.append(f"<TITLE>\n{row.title}\n</TITLE>\n")
    content.append(f"<CONTENT>\n{row.contents}\n</CONTENT>\n")
    content.append("</SECTION>\n\n")

content = "\n".join(content)

# %%
len(content)
# Out:
# 741939

# %%
resp = send(content[:100000], model="gpt-5")

# %%
print(resp.output_text)
# Out:
# Below is an internal, actionable review of your documentation. It includes: (1) a concise summary of key information, (2) a structured list of inconsistencies and errors, and (3) concrete suggestions/corrections to improve clarity and coherence.
#
# 1) Internal summary of key information
#
# About the site and support
# - Docs use richer formatting; navigation via top nav, breadcrumbs, sidebar, ToC, tags, and inter-article links.
# - Report doc site problems via the GitHub issues link; each page shows last updated date and commit details.
# - For other issues/questions, use the JASMIN Help beacon “Ask” contact form (bottom-right).
#
# Account types
# - Standard account: one human user only; manages SSH key/password/roles via Accounts Portal; key must be unique and traceable; can be a responsible user for shared/service accounts; training accounts are short-term standard accounts preset for events.
# - Shared account: used by a small, defined set of responsible users (each uses own SSH key); shared account itself has no SSH key; responsible users’ keys are synced; may set a password (to be shared securely); can apply for roles and act like a standard account; requests reviewed/approved by JASMIN.
# - Service account: used by a service/function only; has responsible users; cannot log into the portal or set passwords; no SSH key; roles granted by arrangement; requests reviewed/approved by JASMIN; notifications go to responsible users (optional service email).
#
# Getting started / login
# - Steps to access JASMIN:
#   1) Generate SSH key on local machine.
#   2) Create a JASMIN Accounts Portal profile and upload public key.
#   3) Request the “jasmin-login” service (creates system account).
#   4) Log in using SSH with agent-forwarding (-A).
#   5–7) Optional: request additional services (e.g., Group Workspaces), get CEDA account if needed, and link JASMIN-CEDA accounts.
# - Use sci servers for development/light interactive tasks; LOTUS for batch/heavy compute; xfer servers for data transfer; NX for graphical desktop within JASMIN.
# - Present SSH key either by specifying -i each time or loading into ssh-agent (recommended). Methods covered for Windows (OpenSSH and MobaXterm), Mac (Keychain), and Linux.
#
# Storage overview and usage
# - Home directories: /home/users/<username>, SSD, 100 GB quota, backed up via snapshots (self-service restore, ~1–2 weeks).
# - Group Workspaces (GWS): main place to write/share project data; storage types include PFS (/gws/pw/j07) and SOF (/gws/nopw/j04). Most GWS are not backed up (except snapshot backups on /gws/smf SSD volumes).
# - Scratch: /work/scratch-pw2, /work/scratch-pw3 (PFS, fast, parallel-write), and /work/scratch-nopw (SSD, fast for small files, no parallel-write). Intended for temporary/intermediate data; auto-cleaned if not accessed for 28 days. Create subdirectories under scratch for your username.
# - /tmp: local on physical sci and LOTUS nodes only; OK for small, node-local temporary files; do not rely on /tmp on virtual sci (not local).
# - CEDA Archive: mounted read-only at /badc, /neodc, etc. Licensing varies; ensure permissions and linked accounts as needed.
# - Symlinks advice: avoid symlinks in home directories to other volumes (can overload metadata servers and hang ls). Prefer environment variable path substitutions.
#
# Backups and snapshot recovery
# - Home directory snapshots at /home/users/.snapshot/homeusers2.<id>/<username>.
# - /gws/smf/<...>/.snapshot retains hourly/daily snapshots.
# - Other GWS volumes are not backed up.
#
# Performance and best practice
# - Avoid >100k files in a single directory.
# - Use \ls to bypass aliases when listing huge directories; be cautious with colored ls and inter-volume symlinks.
# - On SOF storage, avoid parallel writes to the same file; use PFS scratch as an intermediary for MPI-IO workflows; consider global write locking if required (performance tradeoff).
#
# Training accounts
# - Temporary, event-limited accounts with predefined services; event organisers request in advance; attendees receive credentials (via OneDrive), set up their local environment before the event, and may need to set portal/notebook passwords via password reset.
#
# Tips for new users
# - Sci usage guidelines: pick a less-busy sci, avoid heavy/long jobs; use LOTUS for heavy workloads; do not use /tmp or sci for data transfer; avoid hogging IDL dev licenses.
# - LOTUS guidelines: use runtime IDL only; clean up /tmp; don’t leave data in scratch.
# - Xfer guidelines: limit parallel rsync/scp processes; use Globus/hpxfer for heavy transfers.
# - Reporting issues: provide precise path, host, timestamp, and details.
#
# Login/how-to
# - Load your private key locally and connect with ssh -A <user>@login-0X.jasmin.ac.uk, then hop to sci servers; for GUI use NX. X-forwarding only within JASMIN.
#
# JASMIN status
# - CEDA Status page (incidents/maintenance), JASMIN metrics dashboard (GWS, LOTUS, Power, Tape), JASMIN-USERS email list, CEDA News, @cedanews on X.
#
# Managing many Unix groups
# - NFS limits groups in access checks; use newgrp (interactive) or withgroups (non-interactive, via module load jasmin-sci) to run commands under selected groups; use withgroups in scripts/LOTUS.
#
# Windows client: MobaXterm
# - How to install, enable MobAgent to store key, and log in. Alternative: use ssh-agent inside MobaXterm terminal session.
#
# Projects/resources (consortium managers)
# - Use JASMIN Projects Portal to review project records and their requested services/resources.
#
# 2) Inconsistencies, errors, and defects to fix
#
# Typos/grammar/style
# - Issues with this site: “The date of update date and commit message…” -> “The last updated date and commit message…”
# - STANDARD accounts: “one more” -> “one or more”.
# - SHARED accounts:
#   - “changes their the SSH key” -> “changes their SSH key”.
#   - “(re)set a a password” -> “(re)set a password”.
#   - Stray bold marker: “shared securely**” -> “shared securely”.
#   - “obtain an short-lived credential” -> “obtain a short-lived credential”.
# - Start here: stray quote after “available" -> remove the closing double quote.
# - Optional further steps, step 6: “it’s accessible read-only throughout JASMIN, Some” -> “… read-only throughout JASMIN. Some …”
# - Further information: “find about” -> “find out about”.
# - Access to storage: broken Hugo ref shortcode -> {% ref "understanding-new-jasmin-storage" %} (space after ref).
# - Recovering snapshots: path and label inconsistent:
#   - Intro uses “/home/users/.snapshot/homeusers.<snapshotid>” but examples use “homeusers2.”. Make consistent: “homeusers2.<snapshotid>”.
#   - “with a command line this” -> “with a command like this”.
# - JASMIN disk mounts table:
#   - Mixed naming for scratch areas: elsewhere you refer to /work/scratch-nopw and /work/scratch-nopw2 interchangeably. Standardize (pick the actually deployed path).
#   - Consistency of “No/RO/R/W” capitalization.
# - Where to write data:
#   - Leading “0 Group Workspaces …” -> fix to “- Group Workspaces …”.
#   - “onwaards” -> “onwards”.
# - Scratch:
#   - “**** Any data …” -> remove stray asterisks; make a sentence.
#   - “capabale” -> “capable”.
#   - Uses “/work/scratch-nopw2”; other sections use “/work/scratch-nopw”. Standardize.
#   - Placeholder “/work/scratch-????/<username>” -> replace with concrete examples (/work/scratch-pw2/<username>, /work/scratch-pw3/<username>, /work/scratch-nopw/<username>).
# - Cleaning up scratch:
#   - “/tmp`and” -> “/tmp` and”.
#   - “for long periods of tine” -> “… time”.
#   - “/work/scratch-nopw2” again vs earlier “-nopw”. Standardize.
# - Access to the CEDA archive:
#   - “refleting” -> “reflecting”.
#   - “permissions to access data any data” -> remove duplicate “data”.
# - Slow ‘ls’ response:
#   - “aliassed” -> “aliased”.
# - Advice on inter-volume symlinks:
#   - “provided the `stat`” -> “to provide the `stat`”.
#   - “This is happens especially …” -> “This happens especially …”
# - Get a login account:
#   - “Sign in into” -> “Sign in to”.
#   - Step numbering repeats “Step 4” twice. Second one should be “Step 5”.
#   - “You have now access …” -> “You now have access …”
# - “tips-for-new-users” section title: inconsistent casing relative to others; recommend “Tips for new users”.
# - Sci machines usage guidelines:
#   - Path uses legacy “/group_workspaces/jasmin/…”; elsewhere the doc uses “/gws/...”. Standardize to current path conventions.
# - SSH key generation:
#   - Recommends RSA 2048; consider recommending ed25519 as the default (smaller, stronger, faster) if JASMIN supports it.
#   - States private key permission “400”; elsewhere you instruct “chmod 600 …”. Standardize (600 is typical and acceptable).
# - Present SSH key: some Windows OpenSSH instructions have grammar issues and could be streamlined. Make the “optional features” text clearer.
# - Unprotected private key file:
#   - “permisisons” -> “permissions”.
#   - Structural error: The Windows PowerShell code block is split across multiple top-level sections (“Set a variable 'Key' …”, “Remove Inheritance:”, etc.). The opening {{< command … >}} tag is not closed until much later, spanning these separate sections. This will break the page and navigation. All those steps must be consolidated back into the same section with a single code block (or clearly separated code blocks), not split into separate sections.
# - JASMIN status:
#   - “shceduled” -> “scheduled”.
#   - “Currrently” -> “Currently”.
# - How to login:
#   - Minor grammar: “This means that your the information …” -> remove “your” or “the”.
# - “nan” section:
#   - A section with TITLE “nan” appears, containing the tail of a code block and narrative that belongs to the previous section. This indicates a rendering/parsing error (likely from the broken command/code block above). Remove the “nan” section entirely and merge its content back into “Where next?” or the preceding section.
# - Understanding new JASMIN storage:
#   - Has a self-admitted out-of-date warning; ensure the rest of storage docs reflect current Phase 7+ terminology consistently (PFS j07 volumes etc.).
# - Use of workarounds with python:
#   - “lauch” -> “launch”.
# - Incomplete content:
#   - Processing requests for resources (consortium managers) ends mid-sentence: “For a Cloud Tenancy service, these could be requirements for” -> complete the sentence and section.
#
# Structural and cross-referencing issues
# - Mixed reference aliases for Group Workspace docs:
#   - You use both short-term-project-storage and introduction-to-group-workspaces. Confirm canonical slug and reference consistently.
# - Mixed scratch path names (…-nopw vs …-nopw2) across multiple sections and tables.
# - Legacy path “/group_workspaces” vs new “/gws…” across sections (e.g., Sci guidelines vs storage sections).
# - Two different statements on whether scratch is available on transfer servers are consistent (table: “no” for transfer; later text says not available on xfer), so OK. Just ensure table and text agree after standardizing names.
#
# Outdated or policy clarifications likely needed
# - COVID-specific phrasing (“currently being run virtually due to the Covid-19 pandemic”) may be out of date; consider neutral wording or a link to current events page.
# - Key type recommendation: consider ed25519 as default if permitted.
# - Clarify snapshot retention periods (Home: 1–2 weeks; smf: hourly for 10 hours then daily for 2 weeks) consistently and ensure the paths and IDs align.
#
# 3) Suggested corrections and improvements
#
# Standardization, naming, and consistency
# - Scratch volumes: choose one canonical path name and use it everywhere:
#   - If current is /work/scratch-pw2, /work/scratch-pw3, and /work/scratch-nopw, then replace all instances of /work/scratch-nopw2 with /work/scratch-nopw, and remove “????” placeholders with specific examples for per-user subdirectories.
# - Group Workspace paths: standardize to /gws/pw/j07/<project> and /gws/nopw/j04/<project>, dropping references to older /group_workspaces unless you are explicitly documenting legacy systems.
# - Tables: harmonize “R/W” vs “RO” casing and “No/no” capitalization; ensure columns match service availability and are consistent with textual guidance.
# - Step numbering: fix duplicated “Step 4” in “Get a login account” and review all step lists to ensure sequential numbering.
#
# Content fixes (examples with proposed text)
# - Issues with this site:
#   - Current: “The date of update date and commit message…”
#   - Proposed: “The last updated date and the commit message for each page are shown just above the footer.”
# - STANDARD accounts:
#   - “A standard account holder may act as a responsible user on one or more service or shared accounts.”
# - SHARED accounts:
#   - “changes their the SSH key” -> “changes their SSH key”
#   - “(re)set a a password, which may be shared securely** …” -> “(re)set a password, which may be shared securely and only among the responsible users.” Remove stray bold markers.
#   - “obtain an short-lived credential” -> “obtain a short-lived credential”
# - Start here:
#   - Remove trailing quote after “available”.
# - Optional further steps (6):
#   - “…read-only throughout JASMIN. Some datasets in the CEDA Archive require specific agreements…”
# - Recovering snapshots:
#   - Use “/home/users/.snapshot/homeusers2.<snapshotid>/<username>” consistently. “Find the relevant snapshots for your username with a command like this:”
# - Where to write data:
#   - Replace “0 Group Workspaces …” with “- Group Workspaces …”
#   - “onwaards” -> “onwards”
# - Scratch:
#   - Remove stray “****”
#   - “capabale” -> “capable”
#   - Replace placeholder /work/scratch-????/<username> with concrete examples as above.
# - Cleaning up scratch:
#   - Add missing space in “/tmp` and”
#   - “tine” -> “time”
# - Access to the CEDA archive:
#   - “refleting” -> “reflecting”
#   - Remove duplicate “data”
# - Slow ‘ls’ response:
#   - “aliassed” -> “aliased”
# - Inter-volume symlinks:
#   - “to provided the `stat` filesystem metadata” -> “to provide the `stat` filesystem metadata”
#   - “This is happens especially …” -> “This happens especially …”
# - Get a login account:
#   - “Sign in into” -> “Sign in to”
#   - Renumber second “Step 4” to “Step 5”
#   - “You have now access …” -> “You now have access …”
# - Tips for new users:
#   - Title case and unify with other section styles: “Tips for new users”
#   - Update TMPDIR example to /gws path, e.g. “export TMPDIR=/gws/pw/j07/<project>/<username>/tmp”
# - SSH key generation:
#   - Prefer ed25519 by default if allowed:
#     - Example: ssh-keygen -t ed25519 -C "me@somewhere.ac.uk" -f ~/.ssh/id_ed25519_jasmin
#     - Keep RSA 3072/4096 as fallback for legacy clients if needed.
#   - Standardize private key permissions to 600 (consistent with “Unprotected private key file” section) and mention that some clients accept 400 but 600 is typical.
# - Present SSH key (Windows OpenSSH):
#   - Clarify “Optional features” steps and add a short, tested PowerShell-only flow; ensure quotes and names are exact and steps minimal.
# - Unprotected private key file (Windows PowerShell block):
#   - Consolidate all the small “Set a variable… / Remove Inheritance / … / Remove Variable” items back into a single section with one code block, for example:
#
#     PS> $Key = "$env:UserProfile\.ssh\id_rsa_jasmin"
#     PS> Icacls $Key /c /t /Inheritance:d
#     PS> Icacls $Key /c /t /Grant ${env:UserName}:F
#     # If the key is outside %UserProfile%:
#     # PS> TakeOwn /F $Key
#     # PS> Icacls $Key /c /t /Grant:r ${env:UserName}:F
#     PS> Icacls $Key /c /t /Remove:g "Authenticated Users" "Everyone" "Users"
#     PS> Icacls $Key
#
#   - Remove the separate “nan” section and close the orphaned command/code blocks correctly.
# - JASMIN status:
#   - Fix “scheduled” and “Currently”.
# - Where next?/How to login:
#   - “your the information” -> “the information”
#
# Hugo shortcode and linking hygiene
# - Ensure all ref shortcodes have correct syntax and spacing: {{% ref "slug" %}} or {{< ref "slug" >}} (depending on your Hugo setup).
# - Remove any stray, unmatched shortcode tags (e.g., bold markers, command blocks).
# - Check that all internal cross-references refer to a canonical slug (e.g., storage docs: one alias).
# - Verify icons/tags shortcodes render as intended; e.g., {{< icon fas tag >}} usage and links to /tags.
#
# Policy/clarification improvements
# - Prominently and consistently state scratch auto-delete policy (28 days) and that scratch is shared/temporary; consider a single “Scratch policy” box reused across relevant pages.
# - Add a “Key types” note recommending ed25519 as default (if supported), with RSA as fallback.
# - Provide clear guidance on where to put TMPDIR and how to avoid writing to /tmp across all client environments.
# - Reinforce that SOF storage is not suitable for parallel writes; add a concise “Do/Don’t” table under Group Workspaces.
#
# Content completion/outdated notices
# - Complete the “Processing requests for resources” section (Cloud Tenancy resource requirements examples).
# - Review “Understanding new JASMIN storage” for Phase 7+ terminology and align all storage tables and examples accordingly.
# - Update COVID-era phrasing in training materials to neutral wording (e.g., “Workshops may be virtual or in-person; see CEDA events for current details.”)
#
# Quality-of-life improvements
# - Convert very long bullet sections into shorter, scannable bullets; add small “Why this matters” notes where users commonly err (e.g., agent-forwarding, /tmp use).
# - Where you reference commands, always show which side the command is run (local vs JASMIN) consistently, as you do in some sections (user@localhost vs user@sci-…).
# - For tables with many line breaks, consider using simpler lists if the static site generator struggles with complex table markup.
#
# If helpful, I can supply a tracked list of exact text replacements by file/section once you confirm canonical paths (scratch and GWS), the preferred SSH key type, and whether to deprecate legacy /group_workspaces references in favor of /gws.

# %%
resp_100_000 = resp
len(resp_100_000.output_text)
# Out:
# 17729

# %%
resp_741_939 = send(content)

# %%
output = resp_741_939.output_text

# %%
print(output)
# Out:
# Summary — key information (internal)
# - Purpose/Scope
#   - This is the JASMIN user documentation covering: accounts, access, storage, transfers, interactive & batch compute, services (Group Workspaces, Object Store, XFC, Elastic Tape (ET), JDMA, JDMA deprecation → NLDS, Dask Gateway, Pangeo, Notebooks, Globus, GridFTP, rclone, bbcp, rsync/scp/sftp, MobaXterm, NoMachine NX, VSCode remote), Cluster-as-a-Service (Kubernetes, Slurm, NFS), and admin/manager workflows (consortium/GWS managers, project portals).
#   - Mixes user-level how-to, service descriptions, admin procedures, and system operation notes. Many legacy / deprecated items are present.
#
# - Accounts & authentication
#   - Account types: STANDARD (individual; training accounts short-term), SHARED (multiple responsible users with their own SSH keys; shared password allowed but must be shared securely), SERVICE (for daemons/functions; no SSH key; cannot reset password).
#   - JASMIN Accounts Portal is central (create account, upload public key, apply for roles).
#   - SSH public-key authentication is mandatory; private keys must be passphrase-protected and not shared.
#   - Agent/forwarding recommended (ssh -A); instructions for ssh-keygen, ssh-agent, ssh-add, and platform-specific guidance (Mac, Linux, Windows via OpenSSH or MobaXterm).
#   - Linking CEDA account to JASMIN accounts portal for Archive access (openID/consent).
#
# - Services & access roles
#   - jasmin-login: required to access login, sci, xfer, LOTUS.
#   - hpxfer role (legacy) — used to be required for high-performance transfer servers and gridftp; doc contains deprecation notices (role may be no longer required).
#   - dask, orchid, etc. — separate access roles exist for some services.
#   - Projects and consortium managers manage resource requests via JASMIN Projects Portal.
#
# - Storage overview
#   - Four main storage types (Phase 4):
#     - SSD: /home/users and /work/scratch-nopw (good for small files; home backed up; default 100 GB quota).
#     - PFS (parallel) — e.g. /gws/pw/j07, /work/scratch-pw[2,3] (good for parallel IO).
#     - SOF (scale-out filesystem) — /gws/nopw/j04 (good for large volumes, not for lots of small files nor parallel writes).
#     - HPOS (object storage / S3-compatible) — JASMIN Object Store (tenancies, keys, bucket policies).
#   - Home default quota: 100 GB; home snapshots retained ~1-2 weeks.
#   - Group Workspaces (GWS): shared project storage, not backed up by default (managers can use Elastic Tape or JDMA to make secondary copies). GWS volumes live under /gws/pw, /gws/nopw, /gws/smf.
#   - Transfer Cache (XFC): temporary user area with hard (HQ, TB) and temporal quotas (TQ, TB-days); files auto-deleted if quota exceeded or >365 days.
#   - Advice: avoid >100k files in a single directory; avoid inter-volume symlinks from home; avoid writing many small files on SOF; use scratch for intermediates; use /tmp on node-local only for small local data.
#
# - Backups / near-line
#   - Home snapshots: daily, kept 1–2 weeks.
#   - smf SSD volumes have snapshots (hourly 10 hours, daily 2 weeks).
#   - Elastic Tape (ET): for GWS managers to create secondary copies; et_put, et_get, et_ls, et_rm CLI tools; important to NOT remove source files until status is CACHED_SYNCED or SYNCED.
#   - JDMA: an API-based migration app; being superseded by NLDS (note: JDMA docs referenced).
#
# - Data transfer tools & recommendations
#   - Recommended: Globus (new JASMIN Default Collection, ID/link via JASMIN Accounts Portal; CLI, SDK, web).
#   - Alternatives:
#     - GridFTP (legacy; ssh-based or certificate-based gridftp via globus-url-copy is being phased out; doc contains legacy instructions and warnings).
#     - bbcp, lftp, rsync/scp/sftp for smaller or specific use-cases.
#     - rclone (allowed subset of commands; mount/rcd/serve disallowed).
#   - Transfer servers:
#     - xfer-vm-0[1-3] (virtual) — general transfer & cron on xfer-vm-03 (use crontamer).
#     - hpxfer[3,4] — physical high-performance DTNs (hpxfer role deprecated for new servers).
#     - gridftp1 / gridftp2 legacy servers.
#   - Advice: use transfer servers, not sci/login for bulk transfers; do not open excessive concurrent connections; prefer Globus for reliability and performance.
#
# - Compute infrastructure
#   - Interactive: login servers (login-01..04), NX graphical servers (nx1..nx4), sci virtual/physical (sci-vm-01..06, sci-ph-01/02).
#   - Batch: LOTUS cluster (Slurm) - queues: test, short-serial, long-serial, par-single, par-multi, high-mem; job submission and monitoring explained; job arrays, mpirun usage, MPI modules.
#   - ORCHID GPU cluster (NVIDIA A100s) — Orchid partition, separate access role (orchid).
#   - Cluster-as-a-Service (CaaS) in cloud: Kubernetes, Slurm, Pangeo, Identity Manager, NFS shared storage; note many bits about being able to provision tenancies, VMs, cluster templates, and user/group management (FreeIPA + Keycloak).
#
# - Notebook / interactive data science
#   - JASMIN Notebook Service (JupyterHub/JupyterLab): authentication via JASMIN account; default Jaspy Python environment; users can create their own virtualenvs/conda envs and register kernels; Dask Gateway available (provision Dask clusters onto LOTUS); Pangeo on Kubernetes for multi-user scalable Jupyter.
#   - Guidance on creating environments in Notebook service and using them as kernels (pip, conda, ipykernel).
#
# - Developer tooling & remote editors
#   - Guidance for MobaXterm (Windows), VSCode Remote-SSH, NoMachine NX graphical desktop; instructions for sending keys, agent forwarding, and handling key format issues.
#   - jasmin-sci modules and Jaspy environments for Python/R; NAG, IDL information and licensing notes.
#
# - Governance, admin & roles
#   - Resource requests via Projects Portal; consortium managers approve requests and submit for provisioning; GWS managers responsibilities (space management, approvals).
#   - Alerts: GWS Scanner, GWS Alert System, dashboards (mon.jasmin.ac.uk), emails.
#   - Deprecations and migration notes: many deprecation notes scattered (GridFTP, hpxfer role, older CentOS→Rocky9 migration; JDMA → NLDS).
#
# Major inconsistencies, errors, and issues to fix (grouped)
# 1) Outdated/deprecated content and conflicting statements
#   - Many deprecation notes interspersed with older instructions. Examples:
#     - hpxfer role: several places say hpxfer role required for some transfer servers; others say deprecated/no longer needed. Clarify current policy.
#     - GridFTP / globus-url-copy: doc still includes legacy gridftp instructions while recommending Globus as primary; needs a single canonical “legacy” section and a clear migration plan.
#     - JDMA vs NLDS: doc references JDMA extensively but also states NLDS will replace it; clarify status, timelines, and user migration steps.
#     - IDL licensing and Rocky9 migration: several places marked “not yet ready” or licensing unresolved — centralize and update once final.
#   - Action: create “Current status / What to use now” summary at top of each major topic and archive older methods into a clearly labeled “Legacy / Deprecated” appendix.
#
# 2) Broken templates, formatting and stray shortcodes
#   - Many unrendered Hugo/shortcode tokens such as: {{<command>}} open/close mismatches, "{{</command>}}" present in outputs, "{{<link ... >}}", "{{<image ...>}}" etc. These make the doc hard to render and may leak template syntax into the published page.
#   - Example stray tokens: "{{</command>}}" appears multiple times in sections where commands end; several places show raw shortcodes like {{<alert>}} open/close mismatches.
#   - Action: run the content through the site renderer or linter, remove unmatched tags, ensure code blocks are consistent and include exact shells and outputs.
#
# 3) Typographical, grammatical and copy errors (representative)
#   - Misspellings: "re-organise" (fine UK), "onwaards" / "onwaards" (typo), "permisisons", "tine" (time), "permisison", "convering", "joeblogs vs joebloggs" (username inconsistency in examples).
#   - Duplicate headings: there are many repeated "Introduction", "Overview" sections — confusing structure.
#   - Action: run a thorough spell/grammar pass; unify US/UK conventions; reduce duplicate headings.
#
# 4) Consistency & clarity issues (important for security/operations)
#   - Confusing advice on private key copying: one section says “copy private key to new machines if you need to login from multiple machines” — this is a security risk. Elsewhere doc states private keys must not be shared. These contradict.
#     - Fix: strongly recommend generating per-machine keys and add public keys to account, or use agent forwarding / ssh-agent with forwarding; advise against copying private keys except under controlled secure conditions with policy/justification.
#   - Use of OneDrive for training account credential distribution: instructions refer to OneDrive email and password reset; consider security and provide alternate secure ways, or at least emphasize verifying sender and using temporary passwords.
#   - Confusing use of “password” vs “passphrase”: many sections conflate account password (for portal) and SSH key passphrase. Add a clear glossary and emphasize distinctions.
#
# 5) Structural problems and duplicated content
#   - Sections are long and sometimes repeated (e.g., GridFTP over SSH appears multiple times, several similar "get started" flows repeated). This makes it hard to find canonical instructions.
#   - Action: reorganize into a top-level map and single canonical article for each major topic (accounts, storage, transfers, compute, notebooks). Create shorter quickstart checklists with links to detailed pages.
#
# 6) Technical inaccuracies / missing clarifications
#   - Default home quota: doc says 100 GB and "Although you can't directly check usage against your quota" but then shows pdu -sh. Clarify: pdu reports size but not quota; to check quota use portal or contact support.
#   - "You are only allowed to exceed the 100 GB quota for a very brief period" — needs explicit policy: define thresholds / grace periods and consequences.
#   - Confusing advice about /tmp across nodes: clarify differences between local node /tmp (NOT shared) and /work scratch (shared) and where it is mounted.
#   - X11 forwarding: the doc has contradictory statements about -X vs -Y; clarify security/performance and recommend NoMachine NX for GUI to local machines.
#   - Globus authentication: make explicit that JASMIN Default Collection requires linking JASMIN account to Globus identity; steps scattered — centralize with clear CLI examples.
#
# 7) Examples and commands with typos or inconsistent examples
#   - Example UID home snapshots use inconsistent usernames "joebloggs/joeblogs/joebloggs" — unify.
#   - Some code blocks show mismatched fences and outputs; ensure each code snippet includes correct prompt and clear instruction.
#   - Some HTML-like fragments and stray placeholders remain (e.g., "MISSING LINK" or "see XXX").
#
# 8) UX/readability issues
#   - Long pages with many nested subtopics; users will be overwhelmed.
#   - Action: create a condensed “cheat-sheet” quickstart per persona (new user, transfer power user, GWS manager, consortium manager, admin) and reference the deep pages.
#
# Concrete suggested corrections & improvements
# A. Organizational / content-level (high priority)
#   1. Create a canonical overview page with quickstarts:
#      - New user quickstart (create portal account → SSH keygen → add public key → apply for jasmin-login → login → try simple commands)
#      - Transfer quickstart (use Globus recommended; example transfer)
#      - Compute quickstart (submit a small Slurm job example)
#      - Notebook quickstart (open notebook, create venv kernel)
#   2. Reorganize content into separate top-level sections and remove duplication:
#      - Accounts & authentication
#      - Storage & snapshot/backups (home, GWS, scratch, XFC, tape/ET, object store)
#      - Data transfer (Globus first, then other tools as alternatives; clearly label legacy GridFTP instructions)
#      - Compute (login, sci, LOTUS, GPU/ORCHID)
#      - Interactive services (Notebooks, Dask Gateway, Pangeo)
#      - Developer tools (MobaXterm, NX, VSCode Remote)
#      - Admin & project management (GWS management, projects portal, consortia, CaaS)
#   3. Move deprecated/legacy procedures into a "Legacy" appendix and mark with date + plan for decommission.
#
# B. Security and policy (high priority)
#   1. Decide and state a single policy on private keys: do NOT copy private keys to other machines. If multiple machines require authentication, generate distinct key pairs per machine and upload each public key to the portal or use agent forwarding. Remove any content that suggests copying private key files as a general practice.
#   2. Clarify passphrase vs password everywhere (boxed note near the top).
#   3. Consolidate password reset / training-account flow with secure transfer methods (avoid OneDrive if possible; at minimum emphasize code only in encrypted channels).
#
# C. Technical fixes (high priority)
#   1. Fix template shortcodes and unmatched "{{<command>}} / {{</command>}}" tags; ensure code blocks render properly.
#   2. Fix typos and sample usernames (e.g., joebloggs consistently).
#   3. Correct inconsistent statements about what’s required (e.g., hpxfer) — produce a short “As of <date>” status line at top of related pages stating current truth.
#   4. Make Globus the canonical recommended method for transfers — add a brief step-by-step CLI example and a short example of automation using globus task wait.
#
# D. Documentation clarity & UX (medium priority)
#   1. Add a small glossary (SSH, key, passphrase, GWS, SOF, PFS, HPOS, XFC, ET, JDMA, NLDS, DTN).
#   2. Provide a short troubleshooting table for common login issues (agent not forwarded, permission denied, host key verification failed), with the minimal steps to resolve each one.
#   3. Provide small diagrams and a short “Where to put data?” decision tree (home / gws / scratch / xfc / tape / object).
#   4. Provide a single unified “Storage types” table (SSD, PFS, SOF, HPOS) with clear examples of what to use for: small files, parallel writes, backups, sharing externally, and whether backed up.
#
# E. Editing & copy (medium priority)
#   1. Run a full spell-check and grammar pass.
#   2. Ensure consistent use of code formatting and inline command prompts (user@host$...) and remove long verbose examples repeated multiple times.
#   3. Standardize the way warnings and deprecations are displayed; avoid scattering them throughout — use a consistent banner style and a “What changed” or “Why this matters” note.
#
# F. Admin & process (medium priority)
#   1. Add dates to all “Updated” and “Deprecated” notices.
#   2. Provide contact/SLAs for helpdesk responses (e.g., expected response times per issue priority).
#   3. Provide a short “how to request” template for common admin actions (GWS change, training accounts, hpxfer access, object-store tenancy, etc.) to reduce back-and-forth.
#
# Examples of specific textual corrections (illustrative)
# - Replace "The accounts portal profile for the shared account will display, but not allow editing of, the public keys of the responsible users." → clarify: "The portal displays the responsible users' public keys for the shared account but does not allow editing of those keys in the shared-account view; each responsible user must update their own key in their standard account profile."
# - Fix the repeated “Step 4” under “Get a login account” where two steps are numbered Step 4.
# - Remove stray "nan" heading near login example.
# - Fix code example usernames "joeblogs" vs "joebloggs" to single consistent example (e.g., joebloggs).
# - Fix misspelling "onwaards" → "onwards".
# - Fix `scp` example with `mailto:mailto:support@jasmin.ac.uk` malformed link.
#
# Priority plan (recommended)
# 1. Immediate (within 1–2 weeks)
#    - Fix rendering issues: unmatched shortcodes, broken command blocks.
#    - Add a brief “This doc covers X; for current recommended methods see: (Globus, Jaspy, Notebooks, LOTUS)” at top; flag deprecated sections.
#    - Fix security contradictions about private keys and add glossary entry for passphrase vs password.
#    - Consolidate Globus as the recommended transfer method and mark GridFTP as legacy.
#
# 2. Short-term (1–2 months)
#    - Reorganize content into canonical sections, remove duplication.
#    - Correct typos and unify example usernames.
#    - Produce a “Quickstart for new users” page + “Troubleshooting cheat-sheet”.
#
# 3. Medium-term (2–6 months)
#    - Review and update all content affected by the Rocky 9 migration (IDL, GridFTP, services, Nemo).
#    - Update CaaS/cluster docs once Kubernetes/Slurm images and policies finalized.
#    - Implement better automated testing/linting (link-checker, shortcode validation).
#
# If you want I can:
# - produce a short "new user quickstart" page from the doc,
# - or generate a prioritized list of pages to refactor first,
# - or run an automated pass to extract all shortcodes / template tokens and list errors to fix.
#
# Which would you like me to do next?

# %%
print(dir(resp_741_939))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_check_frozen', '_copy_and_set_values', '_get_value', '_iter', '_request_id', 'background', 'construct', 'copy', 'created_at', 'dict', 'error', 'from_orm', 'id', 'incomplete_details', 'instructions', 'json', 'max_output_tokens', 'metadata', 'model', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'object', 'output', 'output_text', 'parallel_tool_calls', 'parse_file', 'parse_obj', 'parse_raw', 'previous_response_id', 'reasoning', 'schema', 'schema_json', 'service_tier', 'status', 'temperature', 'text', 'to_dict', 'to_json', 'tool_choice', 'tools', 'top_p', 'truncation', 'update_forward_refs', 'usage', 'user', 'validate']
